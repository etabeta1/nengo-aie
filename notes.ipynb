# %% [markdown]
# # Notes
#
# Di seguito una lista di errori con le rispettive cause:
#
# Non è stata selezionata la npu giusta nel mlir:
# ```
# terminate called after throwing an instance of 'xrt_core::system_error'
#   what():  DRM_IOCTL_AMDXDNA_CREATE_CTX IOCTL failed (err=22): Invalid argument
# ```
#
# Group_id non corretti:
# ```
# terminate called after throwing an instance of 'std::out_of_range'
#   what():  vector::_M_range_check: __n (which is 65535) >= this->size() (which is 2)
# ```
