# %%
from ElementWiseInc import *

# %%
from ElementWiseInc import *
l = ElementWiseIncBuilder()
with open("ewi.mlir", "w") as f:
    f.write(l.build(32))
# Se ancora non abbastanza dma channels, è possibile utilizzare stride e padding per incodare tutto bene
